# %% [markdown]
# # PythonによるLEGOプログラミング

# %% [markdown]
# これまではcolabを使ってPythonを実行してきました。colabは手軽に使える反面、サーボモータを動かしたり、センサを接続することができません。LEGO　SPIKE HUBを使って音を流したりサーボモータを動かしてみましょう。

# %% [markdown]
# 使うツールはブロックプログラミングの時と同じLEGO SPIKE です。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/document_parts/SPIKE_Legacy.png?raw=true" width=200>

# %% [markdown]
# LEGO SPIKEを起動したら、ブロックではなく、Pythonを選択してください。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/document_parts/LEGO_IDE_New_Project.png?raw=true" width=400>

# %% [markdown]
# プログラミングを開始すると、以下のソースがテンプレートとして表示されます。まずはそのまま実行してみましょう。

# %%
from spike import PrimeHub, LightMatrix, Button, StatusLight, ForceSensor, MotionSensor, Speaker, ColorSensor, App, DistanceSensor, Motor, MotorPair
from spike.control import wait_for_seconds, wait_until, Timer
from math import *

hub = PrimeHub()

hub.light_matrix.show_image('HAPPY')

# %% [markdown]
# LEGO SPIKE HUBのLEDマトリクスにスマイルマークが描かれたと思います。これはshow_image('HAPPY')を実行した結果、ライトマトリクスにスマイルマークが描かれました。イメージはHAPPY以外に大量のイメージが用意されています。好きなイメージ名に変更して実行してみましょう。怒った顔を描くには、show_image()関数の引数として、'ANGRY'を指定します。

# %%
from spike import PrimeHub, LightMatrix, Button, StatusLight, ForceSensor, MotionSensor, Speaker, ColorSensor, App, DistanceSensor, Motor, MotorPair
from spike.control import wait_for_seconds, wait_until, Timer
from math import *

hub = PrimeHub()

hub.light_matrix.show_image('ANGRY')
