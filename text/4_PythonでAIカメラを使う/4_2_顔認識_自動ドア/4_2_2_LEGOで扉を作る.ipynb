# %% [markdown]
# # サーボで扉を開閉する自動扉をLEGOで作ります

# %% [markdown]
# LEGOとサーボを使って扉をつくりましょう。以下は一例です。
#
# <img src='https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_gate.png?raw=true' width=600>

# %% [markdown]
# 使う主なLEGOパーツは以下です。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_parts.png?raw=true" width=400>
#
# まずサーボに扉を取り付けます。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build01.png?raw=true" width=400>
#
# 扉がサーボに取り付けられたところ
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build02.png?raw=true" width=400>
#
# 黄色の土台にサーボを取り付けます
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build03.png?raw=true" width=400>
#
# 黄色の土台にサーボを取り付けます（その２）
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build04.png?raw=true" width=400>
#
# 右側の扉ができました。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build05.png?raw=true" width=400>
#
# 左側の扉も同じように作成します
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build06.png?raw=true" width=400>
#
# 黄色の土台を連結します
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build07.png?raw=true" width=400>
#
# サーボと扉の組み立てまではできました。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build08.png?raw=true" width=400>

# %% [markdown]
# 左側のサーボはポートA、右側のサーボはポートBに接続します。

# %% [markdown]
# 左側のサーボはポートA、右側のサーボはポートBに接続します。
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build09.png?raw=true" width=400>
#
# HUBは横にして接続します（たてのままだと穴の位置が合わないため）
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build10.png?raw=true" width=400>
#
# 黄色の土台のまんなかあたりにHUBを接続してください（おおよそ中央であればOKです）
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build11.png?raw=true" width=400>
#
# 接続完了したところ
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build12.png?raw=true" width=400>
#
# 裏返していた土台を元に戻します。自動扉は完成です
#
# <img src="https://github.com/TomoniCodeAcademy/LEGO-expoert-course/blob/main/img/pictures/HuskyLens_facerecognition_auto_gate_build13.png?raw=true" width=400>
