# %% [markdown]
# # 1-0 Pythonについて
# この章ではPythonの基礎を学びます。Pythonは比較的簡単に勉強できる言われています。シンプルで理解しやすい言語ではありますが、AIの開発等で最もよく使われている言語でもあります。LEGO ExpertコースでもプログラミングはPythonを使います。
#
# 最初にテキストを読んだり先生の説明を聞いただけでは分からないと思いますが、ここではそんなものがあるとだけ覚えておいてください。実際にLEGOを使ってプログラムすると、どうやって使うのか分からなかったり、疑問に思うことが出てきます。その時にまた復習してください。必要に迫られて使ううちに、すこしずつ理解が深まると思います。皆さんがPythonを習得されると高校に進学された後もいろいろ役に立つと思います。
